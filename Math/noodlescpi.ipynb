# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import matplotlib.pyplot as plt

noodles = pd.read_excel(r'C:\Users\nbwan\Python\Data Science\noodles.xlsx')
noodles = noodles.drop('Country', axis=1)
noodles
# Out:
#      2014   2015   2016   2017   2018   2019   2020   2021   2022
# 0   44.40  40.43  38.52  38.97  40.25  41.45  46.35  43.99  45.07
# 1   13.43  13.20  13.01  12.62  12.54  12.52  12.64  13.27  14.26
# 2    5.34   3.26   4.27   5.42   6.06   6.73   6.73   7.56   7.58
# 3    5.50   5.54   5.66   5.66   5.78   5.63   5.97   5.85   5.98
# 4    5.00   4.80   4.92   5.06   5.20   5.43   7.03   8.56   8.48
# 5    4.28   4.08   4.10   4.13   4.40   4.63   5.05   4.98   5.15
# 6    3.32   3.48   3.41   3.75   3.98   3.85   4.47   4.44   4.29
# 7    3.59   3.65   3.83   3.74   3.82   3.90   4.13   3.79   3.95
# 8    3.07   3.07   3.36   3.39   3.46   3.57   3.71   3.63   3.87
# 9    2.37   2.37   2.35   2.23   2.37   2.45   2.72   2.85   2.83
# 10   1.94   1.84   1.57   1.78   1.85   1.91   2.00   2.10   2.20
# 11   1.52   1.54   1.65   1.76   1.82   1.92   2.46   2.62   2.79
# 12   1.11   1.19   1.34   1.48   1.57   1.64   1.54   1.59   1.65
# ...

# %%
cpi = pd.read_excel(r'C:\Users\nbwan\Python\Data Science\noodles.xlsx', sheet_name='cpi')
cpi = cpi.drop('Country', axis=1)
cpi = cpi.replace("..", (14))
cpi
# Out:
# C:\Users\nbwan\AppData\Local\Temp\ipykernel_9476\1892726998.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cpi = cpi.replace("..", (14))
#         2014       2015       2016       2017       2018       2019  \
# 0   1.921642   1.437024   2.000002   1.593136   2.074790   2.899234
# 1   6.394925   6.363121   3.525805   3.808798   3.198346   3.030587
# 2   6.665657   4.906973   4.948216   3.328173   3.938826   3.729506
# 3   2.759227   0.795280  -0.127259   0.484200   0.989095   0.468776
# 4   4.084554   0.631201   2.668248   3.520257   3.539628   2.795824
# 5   1.622223   0.118627   1.261583   2.130110   2.442583   1.812210
# 6   3.597823   0.674193   1.253699   2.853188   5.309347   2.392065
# ...

# %%
x = noodles.values.reshape(-1,1)
y = cpi.values.reshape(-1,1)

# %%
x
# Out:
# array([[44.4 ],
#        [40.43],
#        [38.52],
#        [38.97],
#        [40.25],
#        [41.45],
#        [46.35],
#        [43.99],
#        [45.07],
#        [13.43],
#        [13.2 ],
#        [13.01],
#        [12.62],
#        [12.54],
#        [12.52],
#        [12.64],
#        [13.27],
#        [14.26],
#        [ 5.34],
#        [ 3.26],
#        [ 4.27],
#        [ 5.42],
#        [ 6.06],
#        [ 6.73],
#        [ 6.73],
#        [ 7.56],
#        [ 7.58],
#        [ 5.5 ],
#        [ 5.54],
#        [ 5.66],
#        [ 5.66],
#        [ 5.78],
#        [ 5.63],
#        [ 5.97],
#        [ 5.85],
#        [ 5.98],
#        [ 5.  ],
#        [ 4.8 ],
#        [ 4.92],
#        [ 5.06],
#        [ 5.2 ],
#        [ 5.43],
#        [ 7.03],
#        [ 8.56],
#        [ 8.48],
#        [ 4.28],
#        [ 4.08],
#        [ 4.1 ],
#        [ 4.13],
#        [ 4.4 ],
#        [ 4.63],
#        [ 5.05],
#        [ 4.98],
#        [ 5.15],
#        [ 3.32],
# ...

# %%
y
# Out:
# array([[ 1.92164163],
#        [ 1.43702381],
#        [ 2.00000182],
#        [ 1.593136  ],
#        [ 2.0747904 ],
#        [ 2.89923416],
#        [ 2.41942189],
#        [ 0.98101514],
#        [ 1.97357556],
#        [ 6.39492541],
#        [ 6.36312113],
#        [ 3.52580516],
#        [ 3.80879807],
#        [ 3.19834642],
#        [ 3.03058665],
#        [ 1.92096801],
#        [ 1.56012991],
#        [ 4.20946383],
#        [ 6.66565672],
#        [ 4.90697344],
#        [ 4.94821634],
#        [ 3.32817337],
#        [ 3.93882647],
#        [ 3.72950574],
#        [ 6.62343678],
#        [ 5.13140747],
#        [ 6.69903414],
#        [ 2.75922671],
#        [ 0.79527963],
#        [-0.12725884],
#        [ 0.4841998 ],
#        [ 0.9890946 ],
#        [ 0.46877616],
#        [-0.02499583],
#        [-0.23335278],
#        [ 2.49770278],
#        [ 4.08455447],
#        [ 0.63120091],
#        [ 2.66824817],
#        [ 3.52025689],
#        [ 3.53962806],
# ...

# %%
model = LinearRegression()
model.fit(x,y)
x = sm.add_constant(x)
model = sm.OLS(y,x)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.045
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     6.284
# Date:                Thu, 14 Mar 2024   Prob (F-statistic):             0.0134
# Time:                        17:51:19   Log-Likelihood:                -367.94
# No. Observations:                 135   AIC:                             739.9
# Df Residuals:                     133   BIC:                             745.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.7061      0.384     12.255      0.000       3.947       5.466
# ...
