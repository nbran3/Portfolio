# %%
from bs4 import BeautifulSoup
import requests 
import pandas as pd


try:
    source = requests.get('https://en.wikipedia.org/wiki/List_of_largest_manufacturing_companies_by_revenue')
    source.raise_for_status()

    soup = BeautifulSoup(source.text,'html')

    print(soup)

except Exception as error:
    print(error)

# %%
table = soup.find_all('table')[0]

# %%
world_titles = table.find_all('th')

world_table_titles = [title.text.strip() for title in world_titles]

world_table_titles
# Out:
# ['No.', 'Company', 'Industry', 'Revenue (by US$ billion)', 'Headquarters']

# %%
df2021 = pd.DataFrame(columns= world_table_titles)
df2021
# Out:
# Empty DataFrame
# Columns: [No., Company, Industry, Revenue (by US$ billion), Headquarters]
# Index: []

# %%
column_data = table.find_all('tr')

for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    
    length = len(df2021)
    df2021.loc[length] = individual_row_data

# %%
df2021.to_excel('Companies2021.xlsx')
df2021
# Out:
#    No.                                 Company  \
# 0    1                                   Apple
# 1    2                            Toyota Group
# 2    3                        Volkswagen Group
# 3    4                     Samsung Electronics
# 4    5                                 Foxconn
# 5    6                     Mercedes-Benz Group
# 6    7                         Cardinal Health
# 7    8     China Railway and Engineering Group
# 8    9                                  Huawei
# 9   10                                    Ford
# 10  11                                   Honda
# 11  12                          General Motors
# 12  13                              Mitsubishi
# 13  14                                     BMW
# 14  15                              SAIC Motor
# 15  16                         China Minmetals
# 16  17                               FAW Group
# 17  18                            Hengli Group
# 18  19                 China Baowu Steel Group
# ...

# %%
table = soup.find_all('table')[1]
world_titles = table.find_all('th')

world_table_titles = [title.text.strip() for title in world_titles]

world_table_titles

df2020 = pd.DataFrame(columns= world_table_titles)
df2020
# Out:
# Empty DataFrame
# Columns: [No., Company, Industry, Revenue (by US$ billion), Headquarters]
# Index: []

# %%
column_data = table.find_all('tr')

for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    
    length = len(df2020)
    df2020.loc[length] = individual_row_data

# %%
df2020.to_excel('Companies2020.xlsx')
df2020
# Out:
#     No.                       Company  \
# 0     1              Volkswagen Group
# 1     2                  Toyota Group
# 2     3                         Apple
# 3     4           Samsung Electronics
# 4     5                       Daimler
# ..  ...                           ...
# 95   96            Oracle Corporation
# 96   97                   Tata Motors
# 97   98                     Honeywell
# 98   99                       Fujitsu
# 99  100  China South Industries Group
#
#                                      Industry Revenue (by US$ billion)  \
# 0                                  Automotive                    282.7
# 1                        Engineering, various                 265.172*
# 2   Electronics, telecommunications equipment                  260.174
# 3                        Electronics, various                  197.705
# 4                                  Automotive                  193.346
# ..                                        ...                      ...
# ...

# %%
import pypyodbc
SERVER_NAME = 'DESKTOP-K4HURDS\SQLEXPRESS01'
DATABASE_NAME = 'Projects'

# %%
conn = pypyodbc.connect(f"DRIVER={{SQL Server}};SERVER={SERVER_NAME};DATABASE={DATABASE_NAME};Trusted_Connection=yes;")

cursor = conn.cursor()

cursor.execute('''
    CREATE TABLE Companies2021 (
        [No.] int primary key,
        Company varchar(225),
        Industry varchar(225),
        [Revenue (by US$ billion)] int,
        Headquarters varchar(225)
    )
''')
conn.commit()

cursor.close()
conn.close()

# %%
import pypyodbc
from sqlalchemy import create_engine
from sqlalchemy.engine import URL

SERVER_NAME = 'DESKTOP-K4HURDS\SQLEXPRESS01'
DATABASE_NAME = 'Projects'


Table_name = 'Companies2021'

connection_string = f"""
    DRIVER={{SQL Server}};
    SERVER={SERVER_NAME};
    DATABASE={DATABASE_NAME};
    Trusted_Connection=yes;
"""

## Try-Except statement in case there is an error connecting to the database
try:
    connection_url = URL.create('mssql+pyodbc', query={'odbc_connect': connection_string})
    engine = create_engine(connection_url, module=pypyodbc)

except pypyodbc.Error as db_error:
    print("Database connection error:", db_error)


## Try-Except statement in case there is an error with the file
try:
    Companies2021CSV = pd.read_excel(r'C:\Users\nbwan\Python\Companies2021.xlsx', sheet_name='Sheet1')
except FileNotFoundError:
    print("File not found:", r'c:\Users\nbwan\Python\Companies2021.xlsx')
    
except PermissionError:
    print("Permission error for:", r'c:\Users\nbwan\Python\Companies2021.xlsx')


Companies2021CSV.to_sql(Table_name,engine, if_exists='replace', index=False)
# Out:
# 50

# %%
conn = pypyodbc.connect(f"DRIVER={{SQL Server}};SERVER={SERVER_NAME};DATABASE={DATABASE_NAME};Trusted_Connection=yes;")

cursor = conn.cursor()

cursor.execute('''
    CREATE TABLE Companies2020 (
        [No.] int primary key,
        Company varchar(225),
        Industry varchar(225),
        [Revenue (by US$ billion)] int,
        Headquarters varchar(225)
    )
''')
conn.commit()

cursor.close()
conn.close()

# %%
import pypyodbc
from sqlalchemy import create_engine
from sqlalchemy.engine import URL

SERVER_NAME = 'DESKTOP-K4HURDS\SQLEXPRESS01'
DATABASE_NAME = 'Projects'


Table_name = 'Companies2020'

connection_string = f"""
    DRIVER={{SQL Server}};
    SERVER={SERVER_NAME};
    DATABASE={DATABASE_NAME};
    Trusted_Connection=yes;
"""

## Try-Except statement in case there is an error connecting to the database
try:
    connection_url = URL.create('mssql+pyodbc', query={'odbc_connect': connection_string})
    engine = create_engine(connection_url, module=pypyodbc)

except pypyodbc.Error as db_error:
    print("Database connection error:", db_error)


## Try-Except statement in case there is an error with the file
try:
    Companies2020CSV = pd.read_excel(r'C:\Users\nbwan\Python\Companies2020.xlsx', sheet_name='Sheet1')
except FileNotFoundError:
    print("File not found:", r'C:\Users\nbwan\Python\Companies2020.xlsx')
    
except PermissionError:
    print("Permission error for:", r'C:\Users\nbwan\Python\Companies2020.xlsx')


Companies2020CSV.to_sql(Table_name,engine, if_exists='replace', index=False)
# Out:
# 100
